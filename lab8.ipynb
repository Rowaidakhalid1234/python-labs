# %%
import os

folder_name = "lab_data"

if not os.path.exists(folder_name):
    os.mkdir(folder_name)
    print("Folder created")
else:
    print("Folder already exists")
# Out:
# Folder already exists

# %%
import os

base = "lab_data"

subfolders = ["input", "output", "logs"]

for sub in subfolders:
    path = os.path.join(base, sub)
    if not os.path.exists(path):
        os.mkdir(path)

# %%
import os

path = "lab_data"

for item in os.listdir(path):
    full_path = os.path.join(path, item)
    
    if os.path.isfile(full_path):
        print(item, "-> File")
    elif os.path.isdir(full_path):
        print(item, "-> Directory")
# Out:
# input -> Directory
# logs -> Directory
# output -> Directory

# %%
import os

old_name = "lab_data/logs"
new_name = "lab_data/history"

if os.path.exists(old_name):
    os.rename(old_name, new_name)

# %%
file_path = "lab_data/input/notes.txt"

with open(file_path, "w") as f:
    f.write("Line 1\n")
    f.write("Line 2\n")
    f.write("Line 3\n")
    f.write("Line 4\n")
    f.write("Line 5\n")

# %%
file_path = "lab_data/input/notes.txt"

with open(file_path, "r") as f:
    lines = f.readlines()
    print("Number of lines:", len(lines))
# Out:
# Number of lines: 5

# %%
source = "lab_data/input/notes.txt"
destination = "lab_data/output/summary.txt"

with open(source, "r") as f1:
    content = f1.read()

with open(destination, "w") as f2:
    f2.write(content)

# %%
pip install pyfiglet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyfiglet

text = pyfiglet.figlet_format("rowaidakhalid")

with open("lab_data/output/ascii.txt", "w") as f:
    f.write(text)

print(text)
# Out:
#                         _     _       _    _           _ _     _
#  _ __ _____      ____ _(_) __| | __ _| | _| |__   __ _| (_) __| |
# | '__/ _ \ \ /\ / / _` | |/ _` |/ _` | |/ / '_ \ / _` | | |/ _` |
# | | | (_) \ V  V / (_| | | (_| | (_| |   <| | | | (_| | | | (_| |
# |_|  \___/ \_/\_/ \__,_|_|\__,_|\__,_|_|\_\_| |_|\__,_|_|_|\__,_|

# %%
import os

path = "lab_data/history"

if os.path.exists(path) and len(os.listdir(path)) == 0:
    os.rmdir(path)
    print("Deleted")
else:
    print("Folder not empty or doesn't exist")
# Out:
# Deleted
