# %%
print('welcome to pyhon proramming') #welcome
# Out:
# welcome to pyhon proramming

# %%
name = 'rowaida'
print ( name)
# Out:
# rowaida

# %%
claasname ='proramming'
print (claasname)
# Out:
# proramming

# %%
"""
welcome
"""
# Out:
# '\nwelcome\n'

# %%
studntname='alice'
print(type(studntname))
# Out:
# <class 'str'>

# %%
age='20'
print(type(age))
# Out:
# <class 'str'>

# %%
gpa=3.75
print(type(gpa))
# Out:
# <class 'float'>

# %%
subjects={"math","python","pythsics"}
print(type(subjects))
# Out:
# <class 'set'>

# %%
studntinfo={"id":101,"year":2}
print(type(studntinfo))
# Out:
# <class 'dict'>

# %%
skills={"python","sql"}
print(type(skills))
# Out:
# <class 'set'>

# %%
isenrolled=True
print('isenrolled')
print(type(isenrolled))
# Out:
# isenrolled
# <class 'bool'>

# %%
graduationdata=None
print('graduationdata')
print(type(graduationdata))
# Out:
# graduationdata
# <class 'NoneType'>
